# %%
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup as BS
import requests
import re
import json
import pprint 
import calendar
import datetime

# %matplotlib inline

# %%
poverty = pd.read_csv('../data/single_parent/johnsnowlabs/ACS_2010-2014/povertystatus_bysexage_zcta_2010-2014.csv')

# %%
poverty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33120 entries, 0 to 33119
# Columns: 125 entries, Geographic_ID to Margin_Of_Error_Female_75_And_Over_Above_Poverty_In_Past_12_Months
# dtypes: float64(2), int64(121), object(2)
# memory usage: 31.6+ MB

# %%
poverty.describe()
# Out:
#           FIPS_Code      Latitude     Longitude     Land_Area    Water_Area  \
# count  33120.000000  33120.000000  33120.000000  3.312000e+04  3.312000e+04
# mean   49666.334209     38.836675    -91.016175  2.243665e+08  5.126383e+06
# std    27564.925769      5.356859     15.127859  6.563782e+08  3.368040e+07
# min      601.000000     17.963614   -176.629994  5.094000e+03  0.000000e+00
# 25%    26634.750000     35.400299    -97.246397  2.345809e+07  5.735700e+04
# 50%    49739.000000     39.497405    -88.203745  9.293364e+07  5.781845e+05
# 75%    72123.500000     42.122879    -80.230868  2.293548e+08  2.763718e+06
# max    99929.000000     71.253500    -65.307720  3.478591e+10  2.476479e+09
#
#        Total_Estimate_Population  Total_Margin_Of_Error_Population  \
# count               33120.000000                      33120.000000
# mean                 9354.636655                        442.754438
# std                 13839.796651                        422.625179
# ...

# %%
poverty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33120 entries, 0 to 33119
# Columns: 125 entries, Geographic_ID to Margin_Of_Error_Female_75_And_Over_Above_Poverty_In_Past_12_Months
# dtypes: float64(2), int64(121), object(2)
# memory usage: 31.6+ MB

# %%
poverty.head()
# Out:
#     Geographic_ID  FIPS_Code Geographic_Display_Label   Latitude  Longitude  \
# 0  8600000US00601        601              ZCTA5 00601  18.180556 -66.749962
# 1  8600000US00602        602              ZCTA5 00602  18.361945 -67.175597
# 2  8600000US00603        603              ZCTA5 00603  18.455183 -67.119887
# 3  8600000US00606        606              ZCTA5 00606  18.158345 -66.932911
# 4  8600000US00610        610              ZCTA5 00610  18.295366 -67.125135
#
#    Land_Area  Water_Area  Total_Estimate_Population  \
# 0  166659790      799294                      17914
# 1   79287148     4448757                      40807
# 2   81884524      184093                      51761
# 3  109580065       12487                       6415
# 4   93021368     4171999                      28727
#
#    Total_Margin_Of_Error_Population  \
# 0                               289
# 1                               164
# 2                               671
# 3                               264
# ...

# %%
#### Jupyter notebooks displays 20 columns by default; display all column names in df
poverty.columns.tolist()
#### this database doesn't show male/female householder status with children
#### could be used for geospatial or chloropleth analysis of poverty across the nation by age and sex
# Out:
# ['Geographic_ID',
#  'FIPS_Code',
#  'Geographic_Display_Label',
#  'Latitude',
#  'Longitude',
#  'Land_Area',
#  'Water_Area',
#  'Total_Estimate_Population',
#  'Total_Margin_Of_Error_Population',
#  'Total_Estimate_Below_Poverty_Level_In_Past_12_Months',
#  'Total_Margin_Of_Error_Below_Poverty_Level_In_Past_12_Months',
#  'Estimate_Male_Below_Poverty_In_Past_12_Months',
#  'Margin_Of_Error_Male_Below_Poverty_In_Past_12_Months',
#  'Estimate_Male_Under_5_Below_Poverty_In_Past_12_Months',
#  'Margin_Of_Error_Male_Under_5_Below_Poverty_In_Past_12_Months',
#  'Estimate_Male_5_Years_Below_Poverty_In_Past_12_Months',
#  'Margin_Of_Error_Male_5_Years_Below_Poverty_In_Past_12_Months',
#  'Estimate_Male_6_11_Years_Below_Poverty_In_Past_12_Months',
#  'Margin_Of_Error_Male_6_11_Years_Below_Poverty_In_Past_12_Months',
#  'Estimate_Male_12_14_Years_Below_Poverty_In_Past_12_Months',
#  'Margin_Of_Error_Male_12_14_Years_Below_Poverty_In_Past_12_Months',
# ...

# %%
childbearing = pd.read_csv('../data/single_parent/johnsnowlabs/US_nonmarital_childbearing/US_nonmarital_childbearing_1970-2017.csv')

# %%
childbearing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   Year                                                                    40 non-null     int64
#  1   Live_Births_Per_1000_Unmarried_Women                                    40 non-null     float64
#  2   Live_Births_Per_1000_Unmarried_White_Women                              40 non-null     float64
#  3   Live_Births_Per_1000_Unmarried_Black_Women                              40 non-null     float64
#  4   Live_Births_Per_1000_Unmarried_Asian_Women                              16 non-null     float64
#  5   Live_Births_Per_1000_Unmarried_Hispanic_Women                           28 non-null     float64
# ...

# %%
childbearing.head()
# Out:
#    Year  Live_Births_Per_1000_Unmarried_Women  \
# 0  1970                                  26.4
# 1  1975                                  24.5
# 2  1980                                  29.4
# 3  1981                                  29.5
# 4  1982                                  30.0
#
#    Live_Births_Per_1000_Unmarried_White_Women  \
# 0                                        13.9
# 1                                        12.4
# 2                                        18.1
# 3                                        18.6
# 4                                        19.3
#
#    Live_Births_Per_1000_Unmarried_Black_Women  \
# 0                                        95.5
# 1                                        84.2
# 2                                        81.1
# 3                                        79.4
# 4                                        77.9
#
#    Live_Births_Per_1000_Unmarried_Asian_Women  \
# 0                                         NaN
# ...

# %%
childbearing.describe()
# Out:
#               Year  Live_Births_Per_1000_Unmarried_Women  \
# count    40.000000                             40.000000
# mean   1997.200000                             43.182500
# std      12.264604                             10.861999
# min    1970.000000                             24.500000
# 25%    1987.750000                             37.875000
# 50%    1997.500000                             43.850000
# 75%    2007.250000                             46.000000
# max    2017.000000                             78.700000
#
#        Live_Births_Per_1000_Unmarried_White_Women  \
# count                                   40.000000
# mean                                    36.165000
# std                                     13.502774
# min                                     12.400000
# 25%                                     26.875000
# 50%                                     37.200000
# 75%                                     41.875000
# ...

# %%
childbearing.columns.tolist()
# Out:
# ['Year',
#  'Live_Births_Per_1000_Unmarried_Women',
#  'Live_Births_Per_1000_Unmarried_White_Women',
#  'Live_Births_Per_1000_Unmarried_Black_Women',
#  'Live_Births_Per_1000_Unmarried_Asian_Women',
#  'Live_Births_Per_1000_Unmarried_Hispanic_Women',
#  'Live_Births_Per_1000_Unmarried_White_Not_His_Or_Lat_Women',
#  'Percent_of_Live_Births_To_Unmarried_Mothers',
#  'Percent_of_Live_Births_To_Unmarried_White_Mothers',
#  'Percent_of_Live_Births_To_Unmarried_Black_Mothers',
#  'Percent_of_Live_Births_To_Unmarried_American_Indian_or_Alaska_Mothers',
#  'Percent_of_Live_Births_To_Unmarried_Asian_Mothers',
#  'Percent_of_Live_Births_To_Unmarried_Hispanic_Mothers',
#  'Percent_of_Live_Births_To_Unmarried_Mexican_Mothers',
#  'Percent_of_Live_Births_To_Unmarried_Puerto_Rican_Mothers',
#  'Percent_of_Live_Births_To_Unmarried_Cuban_Mothers',
#  'Percent_of_Live_Births_To_Unmarried_Central_and_South_American_Mothers',
#  'Percent_of_Live_Births_To_Unmarried_Other_Hispanic_Mothers',
# ...

# %%
median_hh_inc = pd.read_csv('../data/single_parent/fred/real_median_hh_inc_1984-2021.csv')

# %%
median_hh_inc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATE           38 non-null     object
#  1   MEHOINUSA672N  38 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 736.0+ bytes

# %%
median_hh_inc.describe()
# Out:
#        MEHOINUSA672N
# count      38.000000
# mean    62985.131579
# std      3983.103402
# min     55828.000000
# 25%     60321.750000
# 50%     62747.500000
# 75%     64892.750000
# max     72808.000000

# %%
median_hh_inc
# Out:
#           DATE  MEHOINUSA672N
# 0   1984-01-01          55828
# 1   1985-01-01          56871
# 2   1986-01-01          58920
# 3   1987-01-01          59624
# 4   1988-01-01          60115
# 5   1989-01-01          61153
# 6   1990-01-01          60370
# 7   1991-01-01          58607
# 8   1992-01-01          58153
# 9   1993-01-01          57843
# 10  1994-01-01          58515
# 11  1995-01-01          60348
# 12  1996-01-01          61225
# 13  1997-01-01          62484
# 14  1998-01-01          64781
# 15  1999-01-01          66385
# 16  2000-01-01          66248
# 17  2001-01-01          64779
# 18  2002-01-01          64047
# 19  2003-01-01          63967
# 20  2004-01-01          63745
# 21  2005-01-01          64427
# 22  2006-01-01          64930
# 23  2007-01-01          65801
# 24  2008-01-01          63455
# 25  2009-01-01          63011
# 26  2010-01-01          61364
# 27  2011-01-01          60428
# 28  2012-01-01          60313
# 29  2013-01-01          62425
# ...

# %%
characteristics = pd.read_csv('../data/single_parent/johnsnowlabs/ACS_2012-2016/characteristics_poverty_zcta_2012-2016.csv')

# %%
characteristics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33120 entries, 0 to 33119
# Data columns (total 45 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   Geographic_ID                                                           33120 non-null  object
#  1   FIPS_Code                                                               33120 non-null  int64
#  2   Geographic_Display_Label                                                33120 non-null  object
#  3   Latitude                                                                33120 non-null  float64
#  4   Longitude                                                               33120 non-null  float64
#  5   Land_Area                                                               33120 non-null  int64
# ...

# %%
characteristics.head()
# Out:
#     Geographic_ID  FIPS_Code Geographic_Display_Label   Latitude  Longitude  \
# 0  8600000US00601        601              ZCTA5 00601  18.180556 -66.749961
# 1  8600000US00602        602              ZCTA5 00602  18.361945 -67.175597
# 2  8600000US00603        603              ZCTA5 00603  18.455183 -67.119887
# 3  8600000US00606        606              ZCTA5 00606  18.158345 -66.932911
# 4  8600000US00610        610              ZCTA5 00610  18.295366 -67.125135
#
#    Land_Area  Water_Area  Estimate_Total  Margin_Of_Error_Total  \
# 0  166659745      799293         17800.0                  299.0
# 1   79307535     4428428         39716.0                  188.0
# 2   81884707      183895         51565.0                  785.0
# 3  109579998       12487          6320.0                  233.0
# 4   93013427     4172060         27976.0                  197.0
#
#    Estimate_Population_One_Race  ...  \
# 0                       17611.0  ...
# 1                       25527.0  ...
# ...

# %%
single_parent_percent = pd.read_csv('../data/single_parent/diversitydatakids/single_parent_percent/single_parent_percent_race_5yr_ACS.csv')

# %%
single_parent_percent.describe()
# Out:
#        total_est  total_se   aian_est   aian_se    api_est    api_se  \
# count   9.000000  9.000000   9.000000  9.000000   9.000000  9.000000
# mean   17.492986  0.016485  29.264897  0.166641  14.153112  0.064369
# std     0.288790  0.002098   0.390682  0.021620   0.122165  0.003549
# min    16.968029  0.012982  28.358513  0.131971  13.866494  0.059052
# 25%    17.325644  0.015172  29.170826  0.147942  14.119246  0.063386
# 50%    17.537714  0.016525  29.436026  0.165958  14.181945  0.064159
# 75%    17.692907  0.017446  29.480175  0.183028  14.233039  0.065783
# max    17.801401  0.019585  29.633123  0.193060  14.268226  0.070450
#
#        asian_est  asian_se  black_est  black_se  ...  nnhwhite_est  \
# count   9.000000  9.000000   9.000000  9.000000  ...      9.000000
# mean   13.837360  0.064418  34.977594  0.047287  ...     28.767285
# std     0.120456  0.003579   0.504607  0.005851  ...      0.342565
# min    13.560236  0.059041  33.964027  0.034843  ...     28.027401
# ...

# %%
single_parent_percent
# Out:
#      geoid           name       year  total_est  total_se   aian_est  \
# 0  01000US  United States  2005-2009  16.968029  0.014323  28.358513
# 1  01000US  United States  2006-2010  17.156507  0.016235  29.007010
# 2  01000US  United States  2007-2011  17.325644  0.017446  29.170826
# 3  01000US  United States  2008-2012  17.502373  0.016525  29.441906
# 4  01000US  United States  2009-2013  17.678785  0.012982  29.436026
# 5  01000US  United States  2010-2014  17.801401  0.015172  29.633123
# 6  01000US  United States  2011-2015  17.773516  0.017332  29.547102
# 7  01000US  United States  2012-2016  17.692907  0.018769  29.480175
# 8  01000US  United States  2013-2017  17.537714  0.019585  29.309395
#
#     aian_se    api_est    api_se  asian_est  ...  nnhwhite_est  nnhwhite_se  \
# 0  0.192440  14.119246  0.065783  13.793163  ...     28.748781     0.201478
# 1  0.193060  14.181945  0.070450  13.854511  ...     28.825993     0.201430
# ...

# %%
fm1 = pd.read_excel('../data/single_parent/census/historical_family_tables/fm1.xls')
fm1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35352\157046038.py in <module>
# ----> 1 fm1 = pd.read_excel('../data/single_parent/census/historical_family_tables/fm1.xls')
#       2 fm1
#
# NameError: name 'pd' is not defined

# %%
hh_by_type = pd.read_excel('../data/single_parent/census/historical_family_tables/fm1.xls', skiprows=7, nrows=80)
pd.set_option('display.max_rows', None)
hh_by_type
# Out:
#      Year  All families    Families with own children under 18  \
# 0     NaN           NaN                                  Total
# 1     NaN           NaN                                    NaN
# 2     NaN           NaN                                    NaN
# 3    2022       84265.0                                  33924
# 4   2021r       83711.0                                  33748
# 5    2021       83907.0                                  33579
# 6    2020       83677.0                                  33464
# 7    2019       83482.0                                  33942
# 8    2018       83088.0                                  34452
# 9    2017       82827.0                                  34292
# 10   2016       82184.0                                  34769
# 11   2015       81716.0                                  34979
# 12  2014s       81353.0                                  34955
# 13   2013       80902.0                                  35058
# ...

# %%
#rename columns to flatten table
hh_by_type = hh_by_type.rename(columns = {'Unnamed: 3': 'Married couple', 'Unnamed: 4': 'One parent families', 'Unnamed: 5': 'Mother only', 'Unnamed: 6': 'Father only'})
#drop prior index rows, drop original rows and keep revised
hh_by_type = hh_by_type.drop(labels=[0, 1, 2, 5, 16, 48, 59]).reset_index(drop=True)
#remove "r" from revised columns
hh_by_type['Year'] = hh_by_type['Year'].replace({'r': ''}, regex=True)
# Out:
#      Year  All families    Families with own children under 18  \
# 0     NaN           NaN                                  Total
# 1     NaN           NaN                                    NaN
# 2     NaN           NaN                                    NaN
# 3    2022       84265.0                                  33924
# 4   2021r       83711.0                                  33748
# 5    2021       83907.0                                  33579
# 6    2020       83677.0                                  33464
# 7    2019       83482.0                                  33942
# 8    2018       83088.0                                  34452
# 9    2017       82827.0                                  34292
# 10   2016       82184.0                                  34769
# 11   2015       81716.0                                  34979
# 12  2014s       81353.0                                  34955
# 13   2013       80902.0                                  35058
# ...

# %%
#clear out spaces in headings
# convert all columns but 'year' to int64
hh_type_1950_2022
# convert year to datetime 'yyyy'

# %%
hh_type_1950_2022
# Out:
#      Year  All families    Families with own children under 18 Married couple  \
# 0    2022       84265.0                                  33924          23345
# 1   2021r       83711.0                                  33748          23222
# 2    2021       83907.0                                  33579          23089
# 3    2020       83677.0                                  33464          23618
# 4    2019       83482.0                                  33942          23735
# ..    ...           ...                                    ...            ...
# 72   1954       41263.0                                  22544          20645
# 73   1953       40877.0                                  21718          19920
# 74   1952       40608.0                                  21353          19606
# 75   1951       39944.0                                  21279          19389
# 76   1950       39303.0                                  20324          18824
#
# ...

# %%
hh_type_1950_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 7 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Year                                    77 non-null     object
#  1   All families                            77 non-null     float64
#  2      Families with own children under 18  77 non-null     object
#  3   Married couple                          77 non-null     object
#  4   One parent families                     77 non-null     object
#  5   Mother only                             77 non-null     object
#  6   Father only                             77 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 4.3+ KB

# %% [markdown]
# Jupyter notebooks shows 20 columns only by default
# #### syntax to force notebook to show all columns
# pd.set_option('max_columns', None)
# #### display all column names in df
# print(df.columns.tolist())
# #### syntax to reset columns
# pd.reset_option('max_columns')

# %% [markdown]
# https://pypi.org/project/pandas-profiling/
#
# from ydata_profiling import ProfileReport
#
# ydata_profiling.version.__version__
#
# #### original syntax [from pandas_profiling import ProfileReport]
#
# profile.to_file(output_file="output_min.html")
#
# prof = ProfileReport(df)
# prof.to_file(output_file='output.html')
#
# #### print minimal report
# profile = ProfileReport(df, minimal=True)
#
# #### only use the first 10000 data points
# prof = ProfileReport(df.sample(n=10000))
# prof.to_file(output_file='output.html')
