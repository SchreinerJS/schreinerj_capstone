# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %matplotlib inline

# %%
percentage_state = pd.read_csv('../data/single_parent/diversitydatakids/states_single_parent_households/single_parent_households_percent_by_state.csv')
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
percentage_state
# Out:
#          geoid                  name       year  total_est  total_se  \
# 0    04000US01               Alabama  2005-2009  18.779615  0.123301
# 1    04000US01               Alabama  2006-2010  18.898424  0.121280
# 2    04000US01               Alabama  2007-2011  19.157753  0.116347
# 3    04000US01               Alabama  2008-2012  19.146364  0.114708
# 4    04000US01               Alabama  2009-2013  19.484272  0.099950
# 5    04000US01               Alabama  2010-2014  19.540770  0.117601
# 6    04000US01               Alabama  2011-2015  19.370239  0.113160
# 7    04000US01               Alabama  2012-2016  19.137510  0.118183
# 8    04000US01               Alabama  2013-2017  19.062851  0.131076
# 9    04000US02                Alaska  2005-2009  17.294136  0.294491
# 10   04000US02                Alaska  2006-2010  17.098627  0.286562
# 11   04000US02                Alaska  2007-2011  17.123201  0.282568
# 12   04000US02                Alaska  2008-2012  17.189150  0.270415
# ...

# %%
percentage_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 31 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   geoid          459 non-null    object
#  1   name           459 non-null    object
#  2   year           459 non-null    object
#  3   total_est      459 non-null    float64
#  4   total_se       459 non-null    float64
#  5   aian_est       459 non-null    float64
#  6   aian_se        459 non-null    float64
#  7   api_est        459 non-null    float64
#  8   api_se         459 non-null    float64
#  9   asian_est      459 non-null    float64
#  10  asian_se       459 non-null    float64
#  11  black_est      459 non-null    float64
#  12  black_se       459 non-null    float64
#  13  hisp_est       459 non-null    float64
#  14  hisp_se        459 non-null    float64
#  15  nhisp_est      459 non-null    float64
#  16  nhisp_se       459 non-null    float64
# ...

# %%
percentage_state = percentage_state.round(2)
percentage_state
# Out:
#          geoid                  name       year  total_est  total_se  \
# 0    04000US01               Alabama  2005-2009      18.78      0.12
# 1    04000US01               Alabama  2006-2010      18.90      0.12
# 2    04000US01               Alabama  2007-2011      19.16      0.12
# 3    04000US01               Alabama  2008-2012      19.15      0.11
# 4    04000US01               Alabama  2009-2013      19.48      0.10
# 5    04000US01               Alabama  2010-2014      19.54      0.12
# 6    04000US01               Alabama  2011-2015      19.37      0.11
# 7    04000US01               Alabama  2012-2016      19.14      0.12
# 8    04000US01               Alabama  2013-2017      19.06      0.13
# 9    04000US02                Alaska  2005-2009      17.29      0.29
# 10   04000US02                Alaska  2006-2010      17.10      0.29
# 11   04000US02                Alaska  2007-2011      17.12      0.28
# 12   04000US02                Alaska  2008-2012      17.19      0.27
# ...

# %%
percentage_state.rename(columns = {'total_est': 'Total Single Parent Households', 'aian_est': 'American Indian, Alaska Native',                                    'api_est': 'Asian or Pacific Islander',
                                   'asian_est': 'Asian', 'black_est': 'Black', 'nhisp_est': 'Not Hispanic or Latino',                                  'nhopi_est': 'Native Hawaiian and Other Pacific Islander',
                                   'nhwhite_est': 'White alone, Not Hispanic or Latino', 'nnhwhite_est': 'Total minus non-Hispanic Whites',
                                   'other_est': 'Some Other Race', 'othermore_est': 'Some Other Race or Two or More Races',                                   'twomore_est': 'Two or More Races',
                                   'white_est': 'White'})
percentage_state
# Out:
#          geoid                  name       year  total_est  total_se  \
# 0    04000US01               Alabama  2005-2009      18.78      0.12
# 1    04000US01               Alabama  2006-2010      18.90      0.12
# 2    04000US01               Alabama  2007-2011      19.16      0.12
# 3    04000US01               Alabama  2008-2012      19.15      0.11
# 4    04000US01               Alabama  2009-2013      19.48      0.10
# 5    04000US01               Alabama  2010-2014      19.54      0.12
# 6    04000US01               Alabama  2011-2015      19.37      0.11
# 7    04000US01               Alabama  2012-2016      19.14      0.12
# 8    04000US01               Alabama  2013-2017      19.06      0.13
# 9    04000US02                Alaska  2005-2009      17.29      0.29
# 10   04000US02                Alaska  2006-2010      17.10      0.29
# 11   04000US02                Alaska  2007-2011      17.12      0.28
# 12   04000US02                Alaska  2008-2012      17.19      0.27
# ...

# %%
percentage_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 31 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   geoid          459 non-null    object
#  1   name           459 non-null    object
#  2   year           459 non-null    object
#  3   total_est      459 non-null    float64
#  4   total_se       459 non-null    float64
#  5   aian_est       459 non-null    float64
#  6   aian_se        459 non-null    float64
#  7   api_est        459 non-null    float64
#  8   api_se         459 non-null    float64
#  9   asian_est      459 non-null    float64
#  10  asian_se       459 non-null    float64
#  11  black_est      459 non-null    float64
#  12  black_se       459 non-null    float64
#  13  hisp_est       459 non-null    float64
#  14  hisp_se        459 non-null    float64
#  15  nhisp_est      459 non-null    float64
#  16  nhisp_se       459 non-null    float64
# ...

# %% [markdown]
# percentage_state.to_csv('../data/single_parent/diversitydatakids/states_single_parent_households/percentage_state_single_parent_hh.csv', index = False)
