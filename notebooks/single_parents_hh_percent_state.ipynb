# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %matplotlib inline

# %% [markdown]
# #### Households that are single parent (percent) by race/ethnicity
# The number of households with a single parent
# (male householder and no wife present or female householder and no husband present)
# divided by the number of households, times 100, for the total population and by race/ethnicity.
#
# By using this data, you agree to abide by diversitydatakids.org's Terms and Conditions.
# Suggested citation: diversitydatakids.org. 2021. “Households that are single parent (percent) by race/ethnicity”, retrieved from https://data.diversitydatakids.org/dataset/11001_2_p-households-that-are-single-parent--percent--by-race-ethnicity?_external=True on Apr 26 2023, calculated from American Community Survey Summary Files
#
# #### Households that are single parent (count) by race/ethnicity
# The number of households with a single parent (male householder and no wife present or female householder and no husband present), for the total population and by race/ethnicity.
#
# By using this data, you agree to abide by diversitydatakids.org's Terms and Conditions.
# Suggested citation: diversitydatakids.org. 2021. “Households that are single parent (count) by race/ethnicity”, retrieved from https://data.diversitydatakids.org/dataset/11001_2_c-households-that-are-single-parent--count--by-race-ethnicity?_external=True on Apr 26 2023, calculated from American Community Survey Summary Files

# %%
percentage_state = pd.read_csv('../data/single_parent/diversitydatakids/states_single_parent_households/single_parent_households_percent_by_state.csv')
percentage_state
# Out:
#          geoid     name       year  total_est  total_se   aian_est   aian_se  \
# 0    04000US01  Alabama  2005-2009  18.779615  0.123301  18.865366  1.813039
# 1    04000US01  Alabama  2006-2010  18.898424  0.121280  20.949463  1.815434
# 2    04000US01  Alabama  2007-2011  19.157753  0.116347  21.793451  1.686798
# 3    04000US01  Alabama  2008-2012  19.146364  0.114708  19.010044  1.411344
# 4    04000US01  Alabama  2009-2013  19.484272  0.099950  18.941387  1.480663
# ..         ...      ...        ...        ...       ...        ...       ...
# 454  04000US56  Wyoming  2009-2013  12.978469  0.297758  36.448334  2.842835
# 455  04000US56  Wyoming  2010-2014  13.168584  0.303664  34.130875  2.508825
# 456  04000US56  Wyoming  2011-2015  13.168184  0.290551  36.763851  2.621991
# 457  04000US56  Wyoming  2012-2016  13.381500  0.325797  37.807739  2.670085
# 458  04000US56  Wyoming  2013-2017  13.010942  0.304991  37.583519  2.682499
#
# ...

# %%
#drop columns not needed
percentage_state.drop(['total_se', 'aian_se', 'api_se', 'asian_se', 'black_se', 'hisp_se', 'nhisp_se', 'nhopi_se', 'nhwhite_se', 'nnhwhite_se', 'other_se', 'othermore_se', 'twomore_se', 'white_se'], axis=1, inplace=True)
percentage_state
# Out:
#          geoid     name       year  total_est   aian_est    api_est  \
# 0    04000US01  Alabama  2005-2009  18.779615  18.865366  13.072568
# 1    04000US01  Alabama  2006-2010  18.898424  20.949463  12.486052
# 2    04000US01  Alabama  2007-2011  19.157753  21.793451  12.390244
# 3    04000US01  Alabama  2008-2012  19.146364  19.010044  11.839359
# 4    04000US01  Alabama  2009-2013  19.484272  18.941387  10.320571
# ..         ...      ...        ...        ...        ...        ...
# 454  04000US56  Wyoming  2009-2013  12.978469  36.448334   8.599695
# 455  04000US56  Wyoming  2010-2014  13.168584  34.130875   5.903614
# 456  04000US56  Wyoming  2011-2015  13.168184  36.763851   5.807201
# 457  04000US56  Wyoming  2012-2016  13.381500  37.807739  11.117825
# 458  04000US56  Wyoming  2013-2017  13.010942  37.583519   9.610390
#
#      asian_est  black_est   hisp_est  nhisp_est  nhopi_est  nhwhite_est  \
# 0    12.814507  35.938931  27.636974  18.626221  19.500000    12.552431
# ...

# %%
percent_sp_state = percentage_state.rename(columns = {'name': 'state', 'total_est': 'total_pop_percent',
                                                      'aian_est': 'American_Indian_Alaska_Native',
                                   'api_est': 'Asian_Pacific_Islander', 'asian_est': 'Asian', 'black_est': 'Black',
                                   'hisp_est': 'Hispanic', 'nhisp_est': 'Not_Hispanic_or_Latino',
                                   'nhopi_est': 'Native_Hawaiian_Other_Pacific_Islander',
                                   'nhwhite_est': 'White_Not_Hispanic_or_Latino', 'nnhwhite_est': 'non_Hispanic_Whites',
                                   'other_est': 'Other_Race', 'othermore_est': 'Some_Other_Race_Alone', 
                                   'twomore_est': 'Two_or_More_Races', 'white_est': 'White'})
percent_sp_state
# Out:
#          geoid    state       year  total_pop_percent  \
# 0    04000US01  Alabama  2005-2009          18.779615
# 1    04000US01  Alabama  2006-2010          18.898424
# 2    04000US01  Alabama  2007-2011          19.157753
# 3    04000US01  Alabama  2008-2012          19.146364
# 4    04000US01  Alabama  2009-2013          19.484272
# ..         ...      ...        ...                ...
# 454  04000US56  Wyoming  2009-2013          12.978469
# 455  04000US56  Wyoming  2010-2014          13.168584
# 456  04000US56  Wyoming  2011-2015          13.168184
# 457  04000US56  Wyoming  2012-2016          13.381500
# 458  04000US56  Wyoming  2013-2017          13.010942
#
#      American_Indian_Alaska_Native  Asian_Pacific_Islander      Asian  \
# 0                        18.865366               13.072568  12.814507
# 1                        20.949463               12.486052  12.546350
# 2                        21.793451               12.390244  12.161604
# ...

# %%
percentage_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   geoid          459 non-null    object
#  1   name           459 non-null    object
#  2   year           459 non-null    object
#  3   total_est      459 non-null    float64
#  4   aian_est       459 non-null    float64
#  5   api_est        459 non-null    float64
#  6   asian_est      459 non-null    float64
#  7   black_est      459 non-null    float64
#  8   hisp_est       459 non-null    float64
#  9   nhisp_est      459 non-null    float64
#  10  nhopi_est      459 non-null    float64
#  11  nhwhite_est    459 non-null    float64
#  12  nnhwhite_est   459 non-null    float64
#  13  other_est      459 non-null    float64
#  14  othermore_est  459 non-null    float64
#  15  twomore_est    459 non-null    float64
#  16  white_est      459 non-null    float64
# ...

# %%
single_parent_state = pd.read_csv('../data/single_parent/diversitydatakids/states_single_parent_households/count_single_parent_hh_state.csv')
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
single_parent_state
# Out:
#          geoid                  name       year  total_est     total_se  \
# 0    04000US01               Alabama  2005-2009     341684  2331.525698
# 1    04000US01               Alabama  2006-2010     344180  2301.194520
# 2    04000US01               Alabama  2007-2011     350830  2264.563805
# 3    04000US01               Alabama  2008-2012     351829  2211.968934
# 4    04000US01               Alabama  2009-2013     358254  1964.586661
# 5    04000US01               Alabama  2010-2014     359975  2268.727586
# 6    04000US01               Alabama  2011-2015     358025  2196.974656
# 7    04000US01               Alabama  2012-2016     354247  2277.476632
# 8    04000US01               Alabama  2013-2017     353939  2516.614060
# 9    04000US02                Alaska  2005-2009      40603   708.076213
# 10   04000US02                Alaska  2006-2010      42447   730.331058
# 11   04000US02                Alaska  2007-2011      43308   723.918470
# ...

# %%
single_parent_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 31 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   geoid          459 non-null    object
#  1   name           459 non-null    object
#  2   year           459 non-null    object
#  3   total_est      459 non-null    int64
#  4   total_se       459 non-null    float64
#  5   aian_se        459 non-null    float64
#  6   aian_est       459 non-null    int64
#  7   api_se         459 non-null    float64
#  8   api_est        459 non-null    int64
#  9   asian_se       459 non-null    float64
#  10  asian_est      459 non-null    int64
#  11  black_se       459 non-null    float64
#  12  black_est      459 non-null    int64
#  13  hisp_se        459 non-null    float64
#  14  hisp_est       459 non-null    int64
#  15  nhisp_se       459 non-null    float64
#  16  nhisp_est      459 non-null    int64
# ...

# %%
#drop columns not needed
single_parent_state.drop(['total_se', 'aian_se', 'api_se', 'asian_se', 'black_se', 'hisp_se', 'nhisp_se', 'nhopi_se', 'nhwhite_se', 'nnhwhite_se', 'other_se', 'othermore_se', 'twomore_se', 'white_se'], axis=1, inplace=True)
single_parent_state
# Out:
#          geoid                  name       year  total_est  aian_est  api_est  \
# 0    04000US01               Alabama  2005-2009     341684      1809     2032
# 1    04000US01               Alabama  2006-2010     344180      2052     2126
# 2    04000US01               Alabama  2007-2011     350830      2163     2159
# 3    04000US01               Alabama  2008-2012     351829      1855     2099
# 4    04000US01               Alabama  2009-2013     358254      1800     1922
# 5    04000US01               Alabama  2010-2014     359975      1785     2272
# 6    04000US01               Alabama  2011-2015     358025      1553     2358
# 7    04000US01               Alabama  2012-2016     354247      1374     2183
# 8    04000US01               Alabama  2013-2017     353939      1474     2315
# 9    04000US02                Alaska  2005-2009      40603      8780     2175
# 10   04000US02                Alaska  2006-2010      42447      9642     2669
# ...

# %%
sp_state = single_parent_state.rename(columns = {'name': 'state', 'total_est': 'total_pop',
                                                 'aian_est': 'American_Indian_Alaska_Native',
                                   'api_est': 'Asian_Pacific_Islander', 'asian_est': 'Asian', 'black_est': 'Black',
                                   'hisp_est': 'Hispanic', 'nhisp_est': 'Not_Hispanic_or_Latino',
                                   'nhopi_est': 'Native_Hawaiian_Other_Pacific_Islander',
                                   'nhwhite_est': 'White_Not_Hispanic_or_Latino', 'nnhwhite_est': 'non_Hispanic_Whites',
                                   'other_est': 'Other_Race', 'othermore_est': 'Some_Other_Race_Alone', 
                                   'twomore_est': 'Two_or_More_Races', 'white_est': 'White'})
sp_state
# Out:
#          geoid                 state       year  total_pop  \
# 0    04000US01               Alabama  2005-2009     341684
# 1    04000US01               Alabama  2006-2010     344180
# 2    04000US01               Alabama  2007-2011     350830
# 3    04000US01               Alabama  2008-2012     351829
# 4    04000US01               Alabama  2009-2013     358254
# 5    04000US01               Alabama  2010-2014     359975
# 6    04000US01               Alabama  2011-2015     358025
# 7    04000US01               Alabama  2012-2016     354247
# 8    04000US01               Alabama  2013-2017     353939
# 9    04000US02                Alaska  2005-2009      40603
# 10   04000US02                Alaska  2006-2010      42447
# 11   04000US02                Alaska  2007-2011      43308
# 12   04000US02                Alaska  2008-2012      43487
# 13   04000US02                Alaska  2009-2013      42931
# 14   04000US02                Alaska  2010-2014      42654
# ...

# %%
sp_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 17 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   geoid                                   459 non-null    object
#  1   state                                   459 non-null    object
#  2   year                                    459 non-null    object
#  3   total_pop                               459 non-null    int64
#  4   American_Indian_Alaska_Native           459 non-null    int64
#  5   Asian_Pacific_Islander                  459 non-null    int64
#  6   Asian                                   459 non-null    int64
#  7   Black                                   459 non-null    int64
#  8   Hispanic                                459 non-null    int64
#  9   Not_Hispanic_or_Latino                  459 non-null    int64
# ...

# %%
#locate needed data
aian = percent_sp_state[['geoid', 'state', 'year', 'total_pop_percent', 'American_Indian_Alaska_Native']]

#create a column for the ethnicity designation
aian['race'] = 'american_indian_alaska_native'
aian

#rename columns
state_percent_aian = aian.rename(columns = {'American_Indian_Alaska_Native': 'percent_sp'})
state_percent_aian.head()
# Out:
# C:\Users\houxu\AppData\Local\Temp\ipykernel_33588\2530306981.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aian['race'] = 'american_indian_alaska_native'
#        geoid    state       year  total_pop_percent  percent_sp  \
# 0  04000US01  Alabama  2005-2009          18.779615   18.865366
# 1  04000US01  Alabama  2006-2010          18.898424   20.949463
# 2  04000US01  Alabama  2007-2011          19.157753   21.793451
# 3  04000US01  Alabama  2008-2012          19.146364   19.010044
# 4  04000US01  Alabama  2009-2013          19.484272   18.941387
#
#                             race
# 0  american_indian_alaska_native
# 1  american_indian_alaska_native
# 2  american_indian_alaska_native
# 3  american_indian_alaska_native
# ...

# %%
#locate needed data
aian_sp = sp_state[['state', 'year', 'total_pop', 'American_Indian_Alaska_Native']]

#create a column for the ethnicity designation
aian_sp['race'] = 'american_indian_alaska_native'
aian_sp

#rename columns
state_sp_aian = aian_sp.rename(columns = {'American_Indian_Alaska_Native': 'sp_est'})
state_sp_aian.head()
# Out:
# C:\Users\houxu\AppData\Local\Temp\ipykernel_33588\3500782065.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aian_sp['race'] = 'american_indian_alaska_native'
#      state       year  total_pop  sp_est                           race
# 0  Alabama  2005-2009     341684    1809  american_indian_alaska_native
# 1  Alabama  2006-2010     344180    2052  american_indian_alaska_native
# 2  Alabama  2007-2011     350830    2163  american_indian_alaska_native
# 3  Alabama  2008-2012     351829    1855  american_indian_alaska_native
# 4  Alabama  2009-2013     358254    1800  american_indian_alaska_native

# %%
aian_merged = pd.merge(state_percent_aian, state_sp_aian, on = ['state', 'year', 'race'], how = 'inner')
aian_merged
# Out:
#          geoid                 state       year  total_pop_percent  \
# 0    04000US01               Alabama  2005-2009          18.779615
# 1    04000US01               Alabama  2006-2010          18.898424
# 2    04000US01               Alabama  2007-2011          19.157753
# 3    04000US01               Alabama  2008-2012          19.146364
# 4    04000US01               Alabama  2009-2013          19.484272
# 5    04000US01               Alabama  2010-2014          19.540770
# 6    04000US01               Alabama  2011-2015          19.370239
# 7    04000US01               Alabama  2012-2016          19.137510
# 8    04000US01               Alabama  2013-2017          19.062851
# 9    04000US02                Alaska  2005-2009          17.294136
# 10   04000US02                Alaska  2006-2010          17.098627
# 11   04000US02                Alaska  2007-2011          17.123201
# 12   04000US02                Alaska  2008-2012          17.189150
# ...

# %%
#locate needed data
api = percent_sp_state[['geoid', 'state', 'year', 'total_pop_percent', 'Asian_Pacific_Islander']]

#create a column for the ethnicity designation
api['race'] = 'asian_pacific_islander'

#rename columns
state_percent_api = api.rename(columns = {'Asian_Pacific_Islander': 'percent_sp'})
state_percent_api.head()
# Out:
# C:\Users\houxu\AppData\Local\Temp\ipykernel_33588\3849727055.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   api['race'] = 'asian_pacific_islander'
#        geoid    state       year  total_pop_percent  percent_sp  \
# 0  04000US01  Alabama  2005-2009          18.779615   13.072568
# 1  04000US01  Alabama  2006-2010          18.898424   12.486052
# 2  04000US01  Alabama  2007-2011          19.157753   12.390244
# 3  04000US01  Alabama  2008-2012          19.146364   11.839359
# 4  04000US01  Alabama  2009-2013          19.484272   10.320571
#
#                      race
# 0  asian_pacific_islander
# 1  asian_pacific_islander
# 2  asian_pacific_islander
# 3  asian_pacific_islander
# 4  asian_pacific_islander

# %%
#locate needed data
api_sp = sp_state[['state', 'year', 'total_pop', 'Asian_Pacific_Islander']]

#create a column for the ethnicity designation
api_sp['race'] = 'asian_pacific_islander'

#rename columns
state_sp_api = api_sp.rename(columns = {'Asian_Pacific_Islander': 'sp_est'})
state_sp_api.head()
# Out:
# C:\Users\houxu\AppData\Local\Temp\ipykernel_33588\247575303.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   api_sp['race'] = 'asian_pacific_islander'
#      state       year  total_pop  sp_est                    race
# 0  Alabama  2005-2009     341684    2032  asian_pacific_islander
# 1  Alabama  2006-2010     344180    2126  asian_pacific_islander
# 2  Alabama  2007-2011     350830    2159  asian_pacific_islander
# 3  Alabama  2008-2012     351829    2099  asian_pacific_islander
# 4  Alabama  2009-2013     358254    1922  asian_pacific_islander

# %%
api_merged = pd.merge(state_percent_api, state_sp_api, on = ['state', 'year', 'race'], how = 'inner')
api_merged
# Out:
#          geoid                 state       year  total_pop_percent  \
# 0    04000US01               Alabama  2005-2009          18.779615
# 1    04000US01               Alabama  2006-2010          18.898424
# 2    04000US01               Alabama  2007-2011          19.157753
# 3    04000US01               Alabama  2008-2012          19.146364
# 4    04000US01               Alabama  2009-2013          19.484272
# 5    04000US01               Alabama  2010-2014          19.540770
# 6    04000US01               Alabama  2011-2015          19.370239
# 7    04000US01               Alabama  2012-2016          19.137510
# 8    04000US01               Alabama  2013-2017          19.062851
# 9    04000US02                Alaska  2005-2009          17.294136
# 10   04000US02                Alaska  2006-2010          17.098627
# 11   04000US02                Alaska  2007-2011          17.123201
# 12   04000US02                Alaska  2008-2012          17.189150
# ...

# %%
#locate needed data
asian = percent_sp_state[['geoid', 'state', 'year', 'total_pop_percent', 'Asian']]

#create a column for the ethnicity designation
asian['race'] = 'asian'

#rename columns
state_percent_asian = asian.rename(columns = {'Asian': 'percent_sp'})
state_percent_asian.head()
# Out:
# C:\Users\houxu\AppData\Local\Temp\ipykernel_33588\60812071.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   asian['race'] = 'asian'
#        geoid    state       year  total_pop_percent  percent_sp   race
# 0  04000US01  Alabama  2005-2009          18.779615   12.814507  asian
# 1  04000US01  Alabama  2006-2010          18.898424   12.546350  asian
# 2  04000US01  Alabama  2007-2011          19.157753   12.161604  asian
# 3  04000US01  Alabama  2008-2012          19.146364   11.671211  asian
# 4  04000US01  Alabama  2009-2013          19.484272    9.877429  asian

# %%
#locate needed data
asian_sp = sp_state[['state', 'year', 'total_pop', 'Asian']]

#create a column for the ethnicity designation
asian_sp['race'] = 'asian'

#rename columns
state_sp_asian = asian_sp.rename(columns = {'Asian': 'sp_est'})
state_sp_asian.head()
# Out:
# C:\Users\houxu\AppData\Local\Temp\ipykernel_33588\2074277676.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   asian_sp['race'] = 'asian'
#      state       year  total_pop  sp_est   race
# 0  Alabama  2005-2009     341684    1915  asian
# 1  Alabama  2006-2010     344180    2064  asian
# 2  Alabama  2007-2011     350830    2062  asian
# 3  Alabama  2008-2012     351829    2012  asian
# 4  Alabama  2009-2013     358254    1789  asian

# %%
asian_merged = pd.merge(state_percent_asian, state_sp_asian, on = ['state', 'year', 'race'], how = 'inner')
asian_merged
# Out:
#          geoid                 state       year  total_pop_percent  \
# 0    04000US01               Alabama  2005-2009          18.779615
# 1    04000US01               Alabama  2006-2010          18.898424
# 2    04000US01               Alabama  2007-2011          19.157753
# 3    04000US01               Alabama  2008-2012          19.146364
# 4    04000US01               Alabama  2009-2013          19.484272
# 5    04000US01               Alabama  2010-2014          19.540770
# 6    04000US01               Alabama  2011-2015          19.370239
# 7    04000US01               Alabama  2012-2016          19.137510
# 8    04000US01               Alabama  2013-2017          19.062851
# 9    04000US02                Alaska  2005-2009          17.294136
# 10   04000US02                Alaska  2006-2010          17.098627
# 11   04000US02                Alaska  2007-2011          17.123201
# 12   04000US02                Alaska  2008-2012          17.189150
# ...

# %%
#locate needed data
asian_sp = sp_state[['state', 'year', 'total_pop', 'Asian']]

#create a column for the ethnicity designation
asian_sp['race'] = 'asian'

#rename columns
state_sp_asian = asian_sp.rename(columns = {'Asian': 'sp_est'})
state_sp_asian.head()
# Out:
# C:\Users\houxu\AppData\Local\Temp\ipykernel_33588\2074277676.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   asian_sp['race'] = 'asian'
#      state       year  total_pop  sp_est   race
# 0  Alabama  2005-2009     341684    1915  asian
# 1  Alabama  2006-2010     344180    2064  asian
# 2  Alabama  2007-2011     350830    2062  asian
# 3  Alabama  2008-2012     351829    2012  asian
# 4  Alabama  2009-2013     358254    1789  asian

# %%
asian_merged = pd.merge(state_percent_asian, state_sp_asian, on = ['state', 'year', 'race'], how = 'inner')
asian_merged
# Out:
#          geoid                 state       year  total_pop_percent  \
# 0    04000US01               Alabama  2005-2009          18.779615
# 1    04000US01               Alabama  2006-2010          18.898424
# 2    04000US01               Alabama  2007-2011          19.157753
# 3    04000US01               Alabama  2008-2012          19.146364
# 4    04000US01               Alabama  2009-2013          19.484272
# 5    04000US01               Alabama  2010-2014          19.540770
# 6    04000US01               Alabama  2011-2015          19.370239
# 7    04000US01               Alabama  2012-2016          19.137510
# 8    04000US01               Alabama  2013-2017          19.062851
# 9    04000US02                Alaska  2005-2009          17.294136
# 10   04000US02                Alaska  2006-2010          17.098627
# 11   04000US02                Alaska  2007-2011          17.123201
# 12   04000US02                Alaska  2008-2012          17.189150
# ...

# %%
#locate needed data
black = percent_sp_state[['geoid', 'state', 'year', 'total_pop_percent', 'Black']]

#create a column for the ethnicity designation
black['race'] = 'black'
black

#rename columns
state_percent_black = black.rename(columns = {'Black': 'percent_sp'})
state_percent_black.head()
# Out:
# C:\Users\houxu\AppData\Local\Temp\ipykernel_33588\3704200176.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   black['race'] = 'black'
#        geoid    state       year  total_pop_percent  percent_sp   race
# 0  04000US01  Alabama  2005-2009          18.779615   35.938931  black
# 1  04000US01  Alabama  2006-2010          18.898424   35.923450  black
# 2  04000US01  Alabama  2007-2011          19.157753   36.192383  black
# 3  04000US01  Alabama  2008-2012          19.146364   35.904518  black
# 4  04000US01  Alabama  2009-2013          19.484272   36.133095  black

# %%
#locate needed data
black_sp = sp_state[['state', 'year', 'total_pop', 'Black']]

#create a column for the ethnicity designation
black_sp['race'] = 'black'

#rename columns
state_sp_black = black_sp.rename(columns = {'Black': 'sp_est'})
state_sp_black.head()
# Out:
# C:\Users\houxu\AppData\Local\Temp\ipykernel_33588\1318462182.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   black_sp['race'] = 'black'
#      state       year  total_pop  sp_est   race
# 0  Alabama  2005-2009     341684  164472  black
# 1  Alabama  2006-2010     344180  161773  black
# 2  Alabama  2007-2011     350830  164844  black
# 3  Alabama  2008-2012     351829  165122  black
# 4  Alabama  2009-2013     358254  167405  black

# %%
black_merged = pd.merge(state_percent_black, state_sp_black, on = ['state', 'year', 'race'], how = 'inner')
black_merged
# Out:
#          geoid                 state       year  total_pop_percent  \
# 0    04000US01               Alabama  2005-2009          18.779615
# 1    04000US01               Alabama  2006-2010          18.898424
# 2    04000US01               Alabama  2007-2011          19.157753
# 3    04000US01               Alabama  2008-2012          19.146364
# 4    04000US01               Alabama  2009-2013          19.484272
# 5    04000US01               Alabama  2010-2014          19.540770
# 6    04000US01               Alabama  2011-2015          19.370239
# 7    04000US01               Alabama  2012-2016          19.137510
# 8    04000US01               Alabama  2013-2017          19.062851
# 9    04000US02                Alaska  2005-2009          17.294136
# 10   04000US02                Alaska  2006-2010          17.098627
# 11   04000US02                Alaska  2007-2011          17.123201
# 12   04000US02                Alaska  2008-2012          17.189150
# ...

# %%
#locate needed data
hispanic = percent_sp_state[['geoid', 'state', 'year', 'total_pop_percent', 'Hispanic']]

#create a column for the ethnicity designation
hispanic['race'] = 'hispanic'

#rename columns
state_percent_hispanic = hispanic.rename(columns = {'Hispanic': 'percent_sp'})
state_percent_hispanic.head()
# Out:
# C:\Users\houxu\AppData\Local\Temp\ipykernel_33588\1293214384.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hispanic['race'] = 'hispanic'
#        geoid    state       year  total_pop_percent  percent_sp      race
# 0  04000US01  Alabama  2005-2009          18.779615   27.636974  hispanic
# 1  04000US01  Alabama  2006-2010          18.898424   26.798672  hispanic
# 2  04000US01  Alabama  2007-2011          19.157753   26.019863  hispanic
# 3  04000US01  Alabama  2008-2012          19.146364   25.540384  hispanic
# 4  04000US01  Alabama  2009-2013          19.484272   25.974592  hispanic

# %%
#locate needed data
hispanic_sp = sp_state[['state', 'year', 'total_pop', 'Hispanic']]

#create a column for the ethnicity designation
hispanic_sp['race'] = 'hispanic'

#rename columns
state_sp_hispanic = hispanic_sp.rename(columns = {'Hispanic': 'sp_est'})
state_sp_hispanic.head()
# Out:
# C:\Users\houxu\AppData\Local\Temp\ipykernel_33588\1505640281.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hispanic_sp['race'] = 'hispanic'
#      state       year  total_pop  sp_est      race
# 0  Alabama  2005-2009     341684    8560  hispanic
# 1  Alabama  2006-2010     344180   10895  hispanic
# 2  Alabama  2007-2011     350830   11162  hispanic
# 3  Alabama  2008-2012     351829   11355  hispanic
# 4  Alabama  2009-2013     358254   11920  hispanic

# %%
hispanic_merged = pd.merge(state_percent_hispanic, state_sp_hispanic, on = ['state', 'year', 'race'], how = 'inner')
hispanic_merged
# Out:
#          geoid                 state       year  total_pop_percent  \
# 0    04000US01               Alabama  2005-2009          18.779615
# 1    04000US01               Alabama  2006-2010          18.898424
# 2    04000US01               Alabama  2007-2011          19.157753
# 3    04000US01               Alabama  2008-2012          19.146364
# 4    04000US01               Alabama  2009-2013          19.484272
# 5    04000US01               Alabama  2010-2014          19.540770
# 6    04000US01               Alabama  2011-2015          19.370239
# 7    04000US01               Alabama  2012-2016          19.137510
# 8    04000US01               Alabama  2013-2017          19.062851
# 9    04000US02                Alaska  2005-2009          17.294136
# 10   04000US02                Alaska  2006-2010          17.098627
# 11   04000US02                Alaska  2007-2011          17.123201
# 12   04000US02                Alaska  2008-2012          17.189150
# ...

# %%
#locate needed data
nhopi = percent_sp_state [['geoid', 'state', 'year', 'total_pop_percent', 'Native_Hawaiian_Other_Pacific_Islander']]

#create a column for the ethnicity designation
nhopi['race'] = 'native_hawaiian_other_pacific_islander'

#rename columns
state_percent_nhopi = nhopi.rename(columns = {'Native_Hawaiian_Other_Pacific_Islander': 'percent_sp'})
state_percent_nhopi.head()
# Out:
# C:\Users\houxu\AppData\Local\Temp\ipykernel_33588\523651112.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nhopi['race'] = 'native_hawaiian_other_pacific_islander'
#        geoid    state       year  total_pop_percent  percent_sp  \
# 0  04000US01  Alabama  2005-2009          18.779615   19.500000
# 1  04000US01  Alabama  2006-2010          18.898424   10.763888
# 2  04000US01  Alabama  2007-2011          19.157753   20.638298
# 3  04000US01  Alabama  2008-2012          19.146364   17.755102
# 4  04000US01  Alabama  2009-2013          19.484272   26.027397
#
#                                      race
# 0  native_hawaiian_other_pacific_islander
# 1  native_hawaiian_other_pacific_islander
# 2  native_hawaiian_other_pacific_islander
# ...

# %%
#locate needed data
nhopi_sp = sp_state[['state', 'year', 'total_pop', 'Native_Hawaiian_Other_Pacific_Islander']]

#create a column for the ethnicity designation
nhopi_sp['race'] = 'native_hawaiian_other_pacific_islander'

#rename columns
state_sp_nhopi = nhopi_sp.rename(columns = {'Native_Hawaiian_Other_Pacific_Islander': 'sp_est'})
state_sp_nhopi.head()
# Out:
# C:\Users\houxu\AppData\Local\Temp\ipykernel_33588\2539464487.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nhopi_sp['race'] = 'native_hawaiian_other_pacific_islander'
#      state       year  total_pop  sp_est  \
# 0  Alabama  2005-2009     341684     117
# 1  Alabama  2006-2010     344180      62
# 2  Alabama  2007-2011     350830      97
# 3  Alabama  2008-2012     351829      87
# 4  Alabama  2009-2013     358254     133
#
#                                      race
# 0  native_hawaiian_other_pacific_islander
# 1  native_hawaiian_other_pacific_islander
# 2  native_hawaiian_other_pacific_islander
# 3  native_hawaiian_other_pacific_islander
# 4  native_hawaiian_other_pacific_islander

# %%
nhopi_merged = pd.merge(state_percent_nhopi, state_sp_nhopi, on = ['state', 'year', 'race'], how = 'inner')
nhopi_merged
# Out:
#          geoid                 state       year  total_pop_percent  \
# 0    04000US01               Alabama  2005-2009          18.779615
# 1    04000US01               Alabama  2006-2010          18.898424
# 2    04000US01               Alabama  2007-2011          19.157753
# 3    04000US01               Alabama  2008-2012          19.146364
# 4    04000US01               Alabama  2009-2013          19.484272
# 5    04000US01               Alabama  2010-2014          19.540770
# 6    04000US01               Alabama  2011-2015          19.370239
# 7    04000US01               Alabama  2012-2016          19.137510
# 8    04000US01               Alabama  2013-2017          19.062851
# 9    04000US02                Alaska  2005-2009          17.294136
# 10   04000US02                Alaska  2006-2010          17.098627
# 11   04000US02                Alaska  2007-2011          17.123201
# 12   04000US02                Alaska  2008-2012          17.189150
# ...

# %%
#locate needed data
white = percent_sp_state [['geoid', 'state', 'year', 'total_pop_percent', 'White']]

#create a column for the ethnicity designation
white['race'] = 'white'

#rename columns
state_percent_white = white.rename(columns = {'White': 'percent_sp'})
state_percent_white.head()
# Out:
# C:\Users\houxu\AppData\Local\Temp\ipykernel_33588\3376568841.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   white['race'] = 'white'
#        geoid    state       year  total_pop_percent  percent_sp   race
# 0  04000US01  Alabama  2005-2009          18.779615   12.785736  white
# 1  04000US01  Alabama  2006-2010          18.898424   13.032632  white
# 2  04000US01  Alabama  2007-2011          19.157753   13.246995  white
# 3  04000US01  Alabama  2008-2012          19.146364   13.300598  white
# 4  04000US01  Alabama  2009-2013          19.484272   13.624473  white

# %%
#locate needed data
white_sp = sp_state[['state', 'year', 'total_pop', 'White']]

#create a column for the ethnicity designation
white_sp['race'] = 'white'

#rename columns
state_sp_white = white_sp.rename(columns = {'White': 'sp_est'})
state_sp_white.head()
# Out:
# C:\Users\houxu\AppData\Local\Temp\ipykernel_33588\2600187726.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   white_sp['race'] = 'white'
#      state       year  total_pop  sp_est   race
# 0  Alabama  2005-2009     341684  167543  white
# 1  Alabama  2006-2010     344180  171358  white
# 2  Alabama  2007-2011     350830  174615  white
# 3  Alabama  2008-2012     351829  175576  white
# 4  Alabama  2009-2013     358254  179220  white

# %%
white_merged = pd.merge(state_percent_white, state_sp_white, on = ['state', 'year', 'race'], how = 'inner')
white_merged
# Out:
#          geoid                 state       year  total_pop_percent  \
# 0    04000US01               Alabama  2005-2009          18.779615
# 1    04000US01               Alabama  2006-2010          18.898424
# 2    04000US01               Alabama  2007-2011          19.157753
# 3    04000US01               Alabama  2008-2012          19.146364
# 4    04000US01               Alabama  2009-2013          19.484272
# 5    04000US01               Alabama  2010-2014          19.540770
# 6    04000US01               Alabama  2011-2015          19.370239
# 7    04000US01               Alabama  2012-2016          19.137510
# 8    04000US01               Alabama  2013-2017          19.062851
# 9    04000US02                Alaska  2005-2009          17.294136
# 10   04000US02                Alaska  2006-2010          17.098627
# 11   04000US02                Alaska  2007-2011          17.123201
# 12   04000US02                Alaska  2008-2012          17.189150
# ...

# %%
# List of dataframes
list = [aian_merged, api_merged, asian_merged, black_merged, hispanic_merged, nhopi_merged, white_merged]  
# concat dataframes
sp_percent_count_state = pd.concat(list, ignore_index=True)

sp_percent_count_state.head()
# Out:
#        geoid    state       year  total_pop_percent  percent_sp  \
# 0  04000US01  Alabama  2005-2009          18.779615   18.865366
# 1  04000US01  Alabama  2006-2010          18.898424   20.949463
# 2  04000US01  Alabama  2007-2011          19.157753   21.793451
# 3  04000US01  Alabama  2008-2012          19.146364   19.010044
# 4  04000US01  Alabama  2009-2013          19.484272   18.941387
#
#                             race  total_pop  sp_est
# 0  american_indian_alaska_native     341684    1809
# 1  american_indian_alaska_native     344180    2052
# 2  american_indian_alaska_native     350830    2163
# 3  american_indian_alaska_native     351829    1855
# 4  american_indian_alaska_native     358254    1800

# %%
sp_percent_count_state.to_csv('../data/single_parent/diversitydatakids/states_single_parent_households/sp_percent_count_state.csv', index = False)

# %% [markdown]
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %% [markdown]
# *make note on table, "based on American Community Surveys estimates"
